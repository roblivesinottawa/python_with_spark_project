# %%
install.packages("ggplot2")
# Out:
# The downloaded binary packages are in
# 	/var/folders/83/_gttb8hn67dfsswspxfpc23w0000gn/T//Rtmp9WqpCU/downloaded_packages

# %%
library("ggplot2")

# %%
df <- read.csv("appl_stock.csv")

# %%
print(head(df))
# Out:
#         Date   Open   High    Low  Close    Volume Adj.Close
# 1 2010-01-04 213.43 214.50 212.38 214.01 123432400  27.72704
# 2 2010-01-05 214.60 215.59 213.25 214.38 150476200  27.77498
# 3 2010-01-06 214.38 215.23 210.75 210.97 138040000  27.33318
# 4 2010-01-07 211.75 212.00 209.05 210.58 119282800  27.28265
# 5 2010-01-08 210.30 212.00 209.06 211.98 111902700  27.46403
# 6 2010-01-11 212.80 213.00 208.45 210.11 115557400  27.22176

# %%
length(df)
# Out:
# [1] 7

# %%
head(df, 5)
# Out:
#   Date       Open   High   Low    Close  Volume    Adj.Close
# 1 2010-01-04 213.43 214.50 212.38 214.01 123432400 27.72704
# 2 2010-01-05 214.60 215.59 213.25 214.38 150476200 27.77498
# 3 2010-01-06 214.38 215.23 210.75 210.97 138040000 27.33318
# 4 2010-01-07 211.75 212.00 209.05 210.58 119282800 27.28265
# 5 2010-01-08 210.30 212.00 209.06 211.98 111902700 27.46403

# %%
typeof(df['Date'])
# Out:
# [1] "list"

# %%
head(df['Open'], 5)
# Out:
#   Open
# 1 213.43
# 2 214.60
# 3 214.38
# 4 211.75
# 5 210.30

# %%
tail(df, 3)
# Out:
#      Date       Open   High   Low    Close  Volume   Adj.Close
# 1760 2016-12-28 117.52 118.02 116.20 116.76 20905900 116.2560
# 1761 2016-12-29 116.45 117.11 116.40 116.73 15039500 116.2261
# 1762 2016-12-30 116.65 117.20 115.43 115.82 30586300 115.3200

# %%
sort(df$High)
# Out:
#    [1]  90.70  91.05  91.62  91.67  91.74  92.00  92.29  92.30  92.44  92.55
#   [11]  92.70  92.75  92.78  93.05  93.45  93.57  93.57  93.66  93.73  93.77
#   [21]  93.88  94.06  94.07  94.07  94.08  94.10  94.12  94.39  94.50  94.52
#   [31]  94.55  94.64  94.66  94.70  94.72  94.72  94.74  94.76  94.82  94.89
#   [41]  95.00  95.05  95.21  95.28  95.40  95.43  95.48  95.55  95.66  95.68
#   [51]  95.70  95.74  95.77  95.89  95.90  95.94  95.95  95.95  95.99  96.04
#   [61]  96.08  96.29  96.35  96.35  96.38  96.47  96.50  96.50  96.57  96.58
#   [71]  96.62  96.63  96.65  96.71  96.76  96.76  96.80  96.84  96.85  96.85
#   [81]  96.88  96.89  96.89  96.89  96.90  96.92  97.10  97.19  97.24  97.32
#   [91]  97.33  97.34  97.45  97.57  97.65  97.67  97.70  97.71  97.72  97.75
#  [101]  97.84  97.84  97.88  97.88  97.88  97.97  98.02  98.09  98.19  98.19
#  [111]  98.21  98.23  98.27  98.41  98.48  98.65  98.70  98.71  98.84  98.89
# ...

# %%
min(df$High)
# Out:
# [1] 90.7

# %%
max(df$High)
# Out:
# [1] 705.07

# %%
top5 <- head(df, 5)

# %%
print(top5)
# Out:
#         Date   Open   High    Low  Close    Volume Adj.Close
# 1 2010-01-04 213.43 214.50 212.38 214.01 123432400  27.72704
# 2 2010-01-05 214.60 215.59 213.25 214.38 150476200  27.77498
# 3 2010-01-06 214.38 215.23 210.75 210.97 138040000  27.33318
# 4 2010-01-07 211.75 212.00 209.05 210.58 119282800  27.28265
# 5 2010-01-08 210.30 212.00 209.06 211.98 111902700  27.46403

# %%
print(top5[1])
# Out:
#         Date
# 1 2010-01-04
# 2 2010-01-05
# 3 2010-01-06
# 4 2010-01-07
# 5 2010-01-08
